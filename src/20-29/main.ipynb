# %%
# 27번 문제

from src.utils import find_longest_quadratic_n

quadratic_999_1000_dict = find_longest_quadratic_n(999, 1000)

longest_a_b = max(quadratic_999_1000_dict, key=quadratic_999_1000_dict.get)

# %%
print(f"Best a and b: {longest_a_b}")

print(f"Longest n: {quadratic_999_1000_dict[longest_a_b]}")

print(f"Product of a and b: {longest_a_b[0] * longest_a_b[1]}")

# %%
# 28번 문제

from src.utils import find_spiral_diagonals

spiral_digonals_sum_1001 = find_spiral_diagonals(1001)

# %%
print(f"Diagonal sum of 1001 x 1001 spiral: {spiral_digonals_sum_1001}")

# %%
# 29번 문제

from src.utils import find_distinct_powers

distinct_powers_100_100 = find_distinct_powers(100, 100)

# %%
print(f"Number of distinct powers of a = 100 & b = 100: {len(distinct_powers_100_100)}")

# %%
# 30번 문제

from src.utils import find_sum_of_nth_powers

sum_of_5th_powers_list = find_sum_of_nth_powers(5)

# %%
print(f"Sum of sum of 5th powers: {sum(sum_of_5th_powers_list)}")

# %%
# 31번 문제

from src.utils import find_coin_sums

pound_coins_200_sums_set = find_coin_sums(200, [200, 100, 50, 20, 10, 5, 2, 1])

# %%
print(f"Number of combinations of 2 pounds: {len(pound_coins_200_sums_set)}")

# %%
# 32번 문제

from src.utils import find_pandigital_products

pandigital_products_set = find_pandigital_products()

# %%
print(f"Sum of all pandigital products: {sum(pandigital_products_set)}")

# %%
# 33번 문제

from src.utils import find_digit_cancelling_fractions

two_digits_cancelling_fractions_list = find_digit_cancelling_fractions(2)

# %%
from fractions import Fraction

numerator = 1
denominator = 1

for fraction in two_digits_cancelling_fractions_list:
    numerator *= fraction[0]
    denominator *= fraction[1]

fraction = Fraction(numerator, denominator)

print(f"Denominator of four fractions: {fraction.denominator}")

# %%
import math

math.factorial(9) * 7

# %%
# 34번 문제

from src.utils import find_digit_factorials

curious_numbers_list = find_digit_factorials()

# %%
print(f"Sum of curious numbers: {sum(curious_numbers_list)}")

# %%
# 35번 문제

from src.utils import find_prime_numbers_by_n, find_circular_primes

prime_number_million_list = find_prime_numbers_by_n(1000000)
circular_prime_million_set = find_circular_primes(prime_number_million_list)

# %%
print(f"Num of circular primes under million: {len(circular_prime_million_set)}")

# %%
# 36번 문제

from src.utils import check_palindrome_numbers

double_based_palindrome_numbers_list = []
for i in range(1, 1000000):
    if check_palindrome_numbers(i) and check_palindrome_numbers(bin(i)[2:]):
        double_based_palindrome_numbers_list.append(i)

# %%
print(f"Sum of double-based palindrom numbers under million: {sum(double_based_palindrome_numbers_list)}")

# %%
# 37번 문제

from src.utils import find_truncatable_primes

truncatable_primes_list = find_truncatable_primes()
# Out:
# 739397

# %%
print(f"Sum of all truncatable primes: {sum(truncatable_primes_list)}")
# Out:
# Sum of all truncatable primes: 748317

# %%
# 38번 문제

from src.utils import find_9_pandigital_multiples

biggest_9_concatenated_product = find_9_pandigital_multiples()

# %%
print(f"The biggest pandigital multiples: {biggest_9_concatenated_product}")
# Out:
# The biggest pandigital multiples: 932718654

# %%
# 39번 문제

from src.utils import find_max_int_right_triangles

right_triangles_dict = {}
for i in range(12, 1001):
    right_triangles_dict[i] = find_max_int_right_triangles(i)

# %%
print(f"P value for maximum solutions number: {max(right_triangles_dict, key=lambda p: len(right_triangles_dict[p]))}")
# Out:
# P value for maximum solutions number: 840

# %%
# 40번 문제

from src.utils import find_champernowne_constant

champernowne_6_constant = find_champernowne_constant(6)

# %%
print(f"Champernowne constant for digit 7: {champernowne_6_constant}")
# Out:
# Champernowne constant for digit 7: 210

# %%
# 41번 문제

from src.utils import find_largest_pandigital_prime

find_largest_pandigital_prime()
