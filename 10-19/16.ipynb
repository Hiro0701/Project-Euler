# %%
def find_power_digit_sum(n: int) -> int:
    return sum([
        int(i) for i in str(2 ** n)
    ])

# %%
power_digit_sum_15 = find_power_digit_sum(15)

power_digit_sum_15
# Out:
# 26

# %%
power_digit_sum_1000 = find_power_digit_sum(1000)

power_digit_sum_1000
# Out:
# 1366
